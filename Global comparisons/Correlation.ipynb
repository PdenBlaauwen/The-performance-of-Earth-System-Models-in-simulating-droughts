# %%
import numpy as np
import scipy.stats as ss
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
from netCDF4 import Dataset

# %%
"""JJA"""

home_b = '/scratch/pdenblaauwen/rootzone/Benchmark_evaporation_products'
home = '/scratch/pdenblaauwen/rootzone/LS3MIP/evspsbl/Monthly_2001-2012/same_resolution/Correlation/'

CESM2_DOLCE_v3_JJA = xr.open_dataset(home + 'JJA/CESM2_DOLCE_v3_JJA_timcor.nc' , engine = 'netcdf4')
CESM2_FBP_JJA = xr.open_dataset(home + 'JJA/CESM2_FBP_JJA_timcor.nc' , engine = 'netcdf4')
CMCC_ESM2_DOLCE_v3_JJA = xr.open_dataset(home + 'JJA/CMCC-ESM2_DOLCE_v3_JJA_timcor.nc' , engine = 'netcdf4')
CMCC_ESM2_FBP_JJA = xr.open_dataset(home + 'JJA/CMCC-ESM2_FBP_JJA_timcor.nc' , engine = 'netcdf4')
E3SM_1_1_DOLCE_v3_JJA = xr.open_dataset(home + 'JJA/E3SM-1-1_DOLCE_v3_JJA_timcor.nc' , engine = 'netcdf4')
E3SM_1_1_FBP_JJA = xr.open_dataset(home + 'JJA/E3SM-1-1_FBP_JJA_timcor.nc' , engine = 'netcdf4')
EC_Earth3_veg_DOLCE_v3_JJA = xr.open_dataset(home + 'JJA/EC-Earth3-veg_DOLCE_v3_JJA_timcor.nc' , engine = 'netcdf4')
EC_Earth3_veg_FBP_JJA = xr.open_dataset(home + 'JJA/EC-Earth3-veg_FBP_JJA_timcor.nc' , engine = 'netcdf4')
HadGEM3_GC31_LL_DOLCE_v3_JJA = xr.open_dataset(home + 'JJA/HadGEM3-GC31-LL_DOLCE_v3_JJA_timcor.nc' , engine = 'netcdf4')
HadGEM3_GC31_LL_FBP_JJA = xr.open_dataset(home + 'JJA/HadGEM3-GC31-LL_FBP_JJA_timcor.nc' , engine = 'netcdf4')
IPSL_CM6A_LR_DOLCE_v3_JJA = xr.open_dataset(home + 'JJA/IPSL-CM6A-LR_DOLCE_v3_JJA_timcor.nc' , engine = 'netcdf4')
IPSL_CM6A_LR_FBP_JJA = xr.open_dataset(home + 'JJA/IPSL-CM6A-LR_FBP_JJA_timcor.nc' , engine = 'netcdf4')
MIROC6_DOLCE_v3_JJA = xr.open_dataset(home + 'JJA/MIROC6_DOLCE_v3_JJA_timcor.nc' , engine = 'netcdf4')
MIROC6_FBP_JJA = xr.open_dataset(home + 'JJA/MIROC6_FBP_JJA_timcor.nc' , engine = 'netcdf4')
UKESM1_0_LL_DOLCE_v3_JJA = xr.open_dataset(home + 'JJA/UKESM1-0-LL_DOLCE_v3_JJA_timcor.nc' , engine = 'netcdf4')
UKESM1_0_LL_FBP_JJA = xr.open_dataset(home + 'JJA/UKESM1-0-LL_FBP_JJA_timcor.nc' , engine = 'netcdf4')

label = ['CESM2' , 'CMCC-ESM2' , 'ESM-1-1' , 'EC-Earth3-veg' , 'HadGEM3-GC31-LL' ,'IPSL-CM6A-LR' ,'MIROC6' ,'UKESM1-0-LL']

# %%
"""Between seperate models and Benchmark evaporation products"""

plt.figure(figsize = (16 , 4))

plt.subplot(121)
CESM2_DOLCE_v3_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[0]} and DOLCE v3 in JJA')
plt.ylim(-60, 90)
plt.grid()


plt.subplot(122)
CESM2_FBP_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[0]} and FBP in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
CMCC_ESM2_DOLCE_v3_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[1]} and DOLCE v3 in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
CMCC_ESM2_FBP_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[1]} and FBP in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
E3SM_1_1_DOLCE_v3_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[2]} and DOLCE v3 in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
E3SM_1_1_FBP_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[2]} and FBP in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
EC_Earth3_veg_DOLCE_v3_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[3]} and DOLCE v3 in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
EC_Earth3_veg_FBP_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[3]} and FBP in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
HadGEM3_GC31_LL_DOLCE_v3_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[4]} and DOLCE v3 in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
HadGEM3_GC31_LL_FBP_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[4]} and FBP in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
IPSL_CM6A_LR_DOLCE_v3_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[5]} and DOLCE v3 in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
IPSL_CM6A_LR_FBP_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[5]} and FBP in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
MIROC6_DOLCE_v3_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[6]} and DOLCE v3 in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
MIROC6_FBP_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[6]} and FBP in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
UKESM1_0_LL_DOLCE_v3_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[7]} and DOLCE v3 in JJA')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
UKESM1_0_LL_FBP_JJA.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[7]} and FBP in JJA')
plt.ylim(-60, 90)
plt.grid()

# %%
"""DJF"""

home_b = '/tudelft.net/staff-umbrella/rootzone/Benchmark_evaporation_products'
home = '/tudelft.net/staff-umbrella/rootzone/LS3MIP/evspsbl/Monthly_2001-2012/same_resolution/Correlation/DJF'

CESM2_DOLCE_v3_DJF = xr.open_dataset(home + '/CESM2_DOLCE_v3_DJF_timcor.nc' , engine = 'netcdf4')
CESM2_FBP_DJF = xr.open_dataset(home + '/CESM2_FBP_DJF_timcor.nc' , engine = 'netcdf4')
CMCC_ESM2_DOLCE_v3_DJF = xr.open_dataset(home + '/CMCC-ESM2_DOLCE_v3_DJF_timcor.nc' , engine = 'netcdf4')
CMCC_ESM2_FBP_DJF = xr.open_dataset(home + '/CMCC-ESM2_FBP_DJF_timcor.nc' , engine = 'netcdf4')
E3SM_1_1_DOLCE_v3_DJF = xr.open_dataset(home + '/E3SM-1-1_DOLCE_v3_DJF_timcor.nc' , engine = 'netcdf4')
E3SM_1_1_FBP_DJF = xr.open_dataset(home + '/E3SM-1-1_FBP_DJF_timcor.nc' , engine = 'netcdf4')
EC_Earth3_veg_DOLCE_v3_DJF = xr.open_dataset(home + '/EC-Earth3-veg_DOLCE_v3_DJF_timcor.nc' , engine = 'netcdf4')
EC_Earth3_veg_FBP_DJF = xr.open_dataset(home + '/EC-Earth3-veg_FBP_DJF_timcor.nc' , engine = 'netcdf4')
HadGEM3_GC31_LL_DOLCE_v3_DJF = xr.open_dataset(home + '/HadGEM3-GC31-LL_DOLCE_v3_DJF_timcor.nc' , engine = 'netcdf4')
HadGEM3_GC31_LL_FBP_DJF = xr.open_dataset(home + '/HadGEM3-GC31-LL_FBP_DJF_timcor.nc' , engine = 'netcdf4')
IPSL_CM6A_LR_DOLCE_v3_DJF = xr.open_dataset(home + '/IPSL-CM6A-LR_DOLCE_v3_DJF_timcor.nc' , engine = 'netcdf4')
IPSL_CM6A_LR_FBP_DJF = xr.open_dataset(home + '/IPSL-CM6A-LR_FBP_DJF_timcor.nc' , engine = 'netcdf4')
MIROC6_DOLCE_v3_DJF = xr.open_dataset(home + '/MIROC6_DOLCE_v3_DJF_timcor.nc' , engine = 'netcdf4')
MIROC6_FBP_DJF = xr.open_dataset(home + '/MIROC6_FBP_DJF_timcor.nc' , engine = 'netcdf4')
UKESM1_0_LL_DOLCE_v3_DJF = xr.open_dataset(home + '/UKESM1-0-LL_DOLCE_v3_DJF_timcor.nc' , engine = 'netcdf4')
UKESM1_0_LL_FBP_DJF = xr.open_dataset(home + '/UKESM1-0-LL_FBP_DJF_timcor.nc' , engine = 'netcdf4')

label = ['CESM2' , 'CMCC-ESM2' , 'ESM-1-1' , 'EC-Earth3-veg' , 'HadGEM3-GC31-LL' ,'IPSL-CM6A-LR' ,'MIROC6' ,'UKESM1-0-LL']

# %%
"""Between seperate models and Benchmark evaporation products"""

plt.figure(figsize = (16 , 4))

plt.subplot(121)
CESM2_DOLCE_v3_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[0]} and DOLCE v3 in DJF')
plt.ylim(-60, 90)
plt.grid()


plt.subplot(122)
CESM2_FBP_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[0]} and FBP in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
CMCC_ESM2_DOLCE_v3_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[1]} and DOLCE v3 in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
CMCC_ESM2_FBP_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[1]} and FBP in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
E3SM_1_1_DOLCE_v3_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[2]} and DOLCE v3 in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
E3SM_1_1_FBP_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[2]} and FBP in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
EC_Earth3_veg_DOLCE_v3_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[3]} and DOLCE v3 in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
EC_Earth3_veg_FBP_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[3]} and FBP in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
HadGEM3_GC31_LL_DOLCE_v3_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[4]} and DOLCE v3 in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
HadGEM3_GC31_LL_FBP_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[4]} and FBP in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
IPSL_CM6A_LR_DOLCE_v3_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[5]} and DOLCE v3 in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
IPSL_CM6A_LR_FBP_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[5]} and FBP in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
MIROC6_DOLCE_v3_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[6]} and DOLCE v3 in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
MIROC6_FBP_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[6]} and FBP in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.figure(figsize = (16 , 4))

plt.subplot(121)
UKESM1_0_LL_DOLCE_v3_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[7]} and DOLCE v3 in DJF')
plt.ylim(-60, 90)
plt.grid()

plt.subplot(122)
UKESM1_0_LL_FBP_DJF.evspsbl.plot(cmap = 'jet' , vmin = -1 , vmax = 1)
plt.title(f'Correlation between {label[7]} and FBP in DJF')
plt.ylim(-60, 90)
plt.grid()
